# %%
import json
def add(m1,n1):
    with open("words.txt",'r') as f1:
        d1=json.load(f1)
    with open("words.txt",'w') as f1:
        d1[m1]=n1
        json.dump(d1,f1)
        print("\n")
        print("Main Menu\n")
        print("1.Add a new word")
        print("2.Find the meaning")
        print("3.Update")
        print("4.Exit")
        n=int(input("Enter Choice :"))
        if (n==1):
                    s1=input("Enter the word : ")
                    r1=input("Enter the meaning of the word : ")
                    add(s1,r1)
        elif (n==2):
                    s2=input("Enter the word : ")
                    find(s2)
        elif (n==3):
                    s3=input("Enter the word you want to update : ")
                    r3=input("Enter the new meaning of the word : ")
                    update(s3,r3)
        else:
                    print("Thank you for using this app")
        
    
def find(m2):
    with open("words.txt",'r') as f2:
        d2=json.load(f2)
        if m2 in d2:
            
                print("The meaning of the word ",m2,"is ",d2[m2])
                print("\n")
                print("Main Menu\n")
                print("1.Add a new word")
                print("2.Find the meaning")
                print("3.Update")
                print("4.Exit")
                n=int(input("Enter Choice :"))
                if (n==1):
                    s1=input("Enter the word : ")
                    r1=input("Enter the meaning of the word : ")
                    add(s1,r1)
                elif (n==2):
                    s2=input("Enter the word : ")
                    find(s2)
                elif (n==3):
                    s3=input("Enter the word you want to update : ")
                    r3=input("Enter the new meaning of the word : ")
                    update(s3,r3)
                else:
                    print("Thank you for using this app")
        else:
                   
                print("The word entered is not present in the dictionary app")
                print("\n")
                print("Main Menu\n")
                print("1.Add a new word")
                print("2.Find the meaning")
                print("3.Update")
                print("4.Exit")
                n=int(input("Enter Choice :"))
                if (n==1):
                    s1=input("Enter the word : ")
                    r1=input("Enter the meaning of the word : ")
                    add(s1,r1)
                elif (n==2):
                    s2=input("Enter the word : ")
                    find(s2)
                elif (n==3):
                    s3=input("Enter the word you want to update : ")
                    r3=input("Enter the new meaning of the word : ")
                    update(s3,r3)
                else:
                    print("Thank you for using this app")

def update(m3,n3):
    with open("words.txt",'w+') as f3:
       d3=json.load(f3)
       if i in d3:
          
                d3[m3]=n3
                print("The new meaning of the word ",m3,"is ",d3[m3])
                print("\n")
                print("Main Menu\n")
                print("1.Add a new word")
                print("2.Find the meaning")
                print("3.Update")
                print("4.Exit")
                n=int(input("Enter Choice :"))
                if (n==1):
                    s1=input("Enter the word : ")
                    r1=input("Enter the meaning of the word : ")
                    add(s1,r1)
                elif (n==2):
                    s2=input("Enter the word : ")
                    find(s2)
                elif (n==3):
                    s3=input("Enter the word you want to update : ")
                    r3=input("Enter the new meaning of the word : ")
                    update(s3,r3)
                else:
                    print("Thank you for using this app")
        
       else:
        
                print("The word entered is not present in the dictionary app")
                print("\n")
                print("Main Menu\n")
                print("1.Add a new word")
                print("2.Find the meaning")
                print("3.Update")
                print("4.Exit")
                n=int(input("Enter Choice :"))
                if (n==1):
                    s1=input("Enter the word : ")
                    r1=input("Enter the meaning of the word : ")
                    add(s1,r1)
                elif (n==2):
                    s2=input("Enter the word : ")
                    find(s2)
                elif (n==3):
                    s3=input("Enter the word you want to update : ")
                    r3=input("Enter the new meaning of the word : ")
                    update(s3,r3)
                else:
                    print("Thank you for using this app")
    
    



def main_menu():
    print("Main Menu\n")
    print("1.Add a new word")
    print("2.Find the meaning")
    print("3.Update")
    print("4.Exit")
    n=int(input("Enter Choice :"))
    if (n==1):
        s1=input("Enter the word : ")
        r1=input("Enter the meaning of the word : ")
        add(s1,r1)
    elif (n==2):
        s2=input("Enter the word : ")
        find(s2)
    elif (n==3):
        s3=input("Enter the word you want to update : ")
        r3=input("Enter the new meaning of the word : ")
        update(s3,r3)
    else:
        print("Thank you for using this app")
import json
with open("words.txt","w") as f:
    d={"affable":"friendly","plaudits":"aprreciation","leverage":"use to maximum advantage","establish":"to set up","interact":"connect"}
    json.dump(d,f)

main_menu()
# Out:
# Main Menu
#
# 1.Add a new word
# 2.Find the meaning
# 3.Update
# 4.Exit
# Enter Choice :2
# Enter the word : affable
# The meaning of the word  affable is  friendly
#
#
# Main Menu
#
# 1.Add a new word
# 2.Find the meaning
# 3.Update
# 4.Exit
# Enter Choice :1
# Enter the word : increase
# Enter the meaning of the word : add
#
#
# Main Menu
#
# 1.Add a new word
# 2.Find the meaning
# 3.Update
# 4.Exit
# Enter Choice :4
# Thank you for using this app
