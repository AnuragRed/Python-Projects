# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\hi\Documents\Python Scripts\auto.csv")

# %%
df.shape #204 records and 26 columns
# Out:
# (204, 26)

# %%
df.columns #Column names are missing therefore the first record is taken to be the column name
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.6', '168.8', '64.1', '48.8', '2548', 'dohc', 'four', '130',
#        'mpfi', '3.47', '2.68', '9.0', '111', '5000', '21', '27', '13495'],
#       dtype='object')

# %%
df1=pd.read_csv(r"C:\Users\hi\Documents\Python Scripts\auto.csv",na_values='?')# including the missing value(?) in the null values

# %%
df1.columns=['symboling','Normalized_losses','CarName', 'fueltype', 'aspiration',
       'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
       'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
       'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
       'price']

# %%
df1.isnull().sum()
# Out:
# symboling             0
# Normalized_losses    40
# CarName               0
# fueltype              0
# aspiration            0
# doornumber            2
# carbody               0
# drivewheel            0
# enginelocation        0
# wheelbase             0
# carlength             0
# carwidth              0
# carheight             0
# curbweight            0
# enginetype            0
# cylindernumber        0
# enginesize            0
# fuelsystem            0
# boreratio             4
# stroke                4
# compressionratio      0
# horsepower            2
# peakrpm               2
# citympg               0
# highwaympg            0
# price                 4
# dtype: int64

# %%
df1["Normalized_losses"].fillna(df1["Normalized_losses"].mean(),inplace=True)

# %%
df1["doornumber"].value_counts()
# Out:
# four    114
# two      88
# Name: doornumber, dtype: int64

# %%
df1["doornumber"].fillna("four",inplace=True)# Because of the higher frequency of four we fill four

# %%
df1["boreratio"].fillna(df1["boreratio"].mean(),inplace=True)

# %%
df1["stroke"].fillna(df1["stroke"].mean(),inplace=True)

# %%
df1["horsepower"].fillna(df1["horsepower"].mean(),inplace=True)

# %%
df1["peakrpm"].fillna(df1["peakrpm"].mean(),inplace=True)

# %%
df1["price"].fillna(df1["price"].mean(),inplace=True)

# %%
df1.isnull().sum() #No Null values left
# Out:
# symboling            0
# Normalized_losses    0
# CarName              0
# fueltype             0
# aspiration           0
# doornumber           0
# carbody              0
# drivewheel           0
# enginelocation       0
# wheelbase            0
# carlength            0
# carwidth             0
# carheight            0
# curbweight           0
# enginetype           0
# cylindernumber       0
# enginesize           0
# fuelsystem           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %% [markdown]
# # Descriptive Analysis

# %%
import matplotlib.pyplot as plt
df1.describe()
# Out:
#         symboling  Normalized_losses   wheelbase   carlength    carwidth  \
# count  204.000000         204.000000  204.000000  204.000000  204.000000
# mean     0.823529         122.000000   98.806373  174.075000   65.916667
# std      1.239035          31.758944    5.994144   12.362123    2.146716
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.075000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.200000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#         carheight   curbweight  enginesize   boreratio     stroke  \
# count  204.000000   204.000000  204.000000  204.000000  204.00000
# mean    53.749020  2555.602941  126.892157    3.329050    3.25830
# std      2.424901   521.960820   41.744569    0.271331    0.31175
# ...

# %%
df1.describe(include=['object']) # 184 cars out of 204 have gas fuel type,201 have engine at the front location so these variables  
# are not very consequential in understanding the patterns
# Out:
#        CarName fueltype aspiration doornumber carbody drivewheel  \
# count      204      204        204        204     204        204
# unique      22        2          2          2       5          3
# top     toyota      gas        std       four   sedan        fwd
# freq        32      184        167        116      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             204        204            204        204
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              201        148            158         93

# %%
sns.relplot(x="citympg",y="price",hue="drivewheel",data=df1)# We can clearly see that the cars with fwd drivewheel are cheaper
# We can also see that cars with rwd and 4wd drivewheel give low city mileage in comparison to fwd

# %%
sns.relplot(x="citympg",y="price",hue="doornumber",data=df1)# The data is quite evenly spread so not much inference can be drawn

# %%
sns.relplot(x="citympg",y="price",hue="aspiration",data=df1)# All the peak prices are occupied by std aspiration
# Most of the cheaper end cars are also std aspiration
# turbo cars are in the mid zone both price and mileage wise

# %%
sns.relplot(x="citympg",y="price",hue="carbody",data=df1)# We can see from this graph that the hardtop and sedan cars are relatively expensive  
# All the hatchback and wagon cars are on the cheaper end
# Almost all the hardtop cars and convertibles have low mileage

# %%
# Let us study the histograms 
import seaborn as sns
sns.displot(df1["price"])# the distribution is skewing towards the lest
# Out:
# 1.8234985824535697

# %%
sns.distplot(df1["citympg"],bins=10)# MOst of the cars have mileage around 25 and 18
# Out:
# C:\Users\hi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='citympg', ylabel='Density'>

# %%
df2=df1.select_dtypes(exclude='object')# for visual analysis we remove the categorical columns

# %%
column=["price","horsepower","citympg"]
df3=pd.DataFrame(df2,columns=column)#Let us study the cars with respect to three variables price,horsepower and citympg

# %%
cor=df3.corr()
sns.heatmap(cor,xticklabels=cor.columns,yticklabels=cor.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df3)
